# %%
#CSE V1 DATASET 0.03 FRACTION

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import logging
import shap
import random
import time
import networkx as nx
import tensorflow as tf
import shap
from contextlib import nullcontext  # <-- place at top-level once
from sklearn.feature_selection import mutual_info_classif, chi2
from sklearn.preprocessing import MinMaxScaler, LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from tensorflow.keras.utils import plot_model
from tensorflow.keras.mixed_precision import global_policy, set_global_policy
from lime.lime_tabular import LimeTabularExplainer
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import precision_recall_fscore_support
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from imblearn.combine import SMOTEENN
from tensorflow.keras.mixed_precision import LossScaleOptimizer, set_global_policy
from sklearn.metrics import confusion_matrix
from sklearn.metrics import (
    confusion_matrix,
    roc_auc_score,
    roc_curve,
    classification_report, auc
)
from sklearn.model_selection import train_test_split
from lime.lime_tabular import LimeTabularExplainer

print("All imported")
# Out:
# All imported

# %%
# Check GPU availability
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# Optional: Limit to first GPU and set memory growth
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.set_visible_devices(gpus[0], 'GPU')
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# Num GPUs Available:  1

# %%
# Create plots directory
plots_dir = "/home/g_kirubavathi/Amal/1_XNFT_R1/R2/plots_r2_NF-CSE-CIC-IDS2018."
os.makedirs(plots_dir, exist_ok=True) 

logging.basicConfig(level=logging.INFO)

# %%
def encode_attack_label(df, label_col="Attack", benign_label="Benign"):
    df = df.copy()
    df[label_col] = (df[label_col] != benign_label).astype(int)  # Benign=0, DDoS=1
    return df




def clean_dataset(X):
    """
    Cleans the dataset by:
    - Replacing infinite values with NaN.
    - Replacing NaN values using the mean of each column.
    - Ensuring all values fit within the float32 range.
    """
    # Convert to DataFrame (if not already)
    if not isinstance(X, pd.DataFrame):
        X = pd.DataFrame(X)
    
    # Replace infinity with NaN
    X.replace([np.inf, -np.inf], np.nan, inplace=True)
    
    # Impute NaN values with column mean
    imputer = SimpleImputer(strategy="mean")
    X_imputed = pd.DataFrame(imputer.fit_transform(X), columns=X.columns)

    # Clip values to avoid float32 overflow (handling extremely large values)
    X_clipped = X_imputed.clip(lower=-1e10, upper=1e10)

    # # Final check for remaining infinite or NaN values
    # if X_imputed.isnull().sum().sum() > 0:
    #     raise ValueError("There are still NaN values present in the dataset.")
    # if np.isinf(X_imputed.values).sum() > 0:
    #     raise ValueError("There are still infinite values present in the dataset.")

    if X_clipped.isnull().sum().sum() > 0:
        raise ValueError("There are still NaN values present in the dataset.")
    if np.isinf(X_clipped.values).sum() > 0:
        raise ValueError("There are still infinite values present in the dataset.")


    
    print("Dataset successfully cleaned and prepared.")
    return X_clipped

# Balance the Dataset by Stratified Sampling
def balance_dataset_stratified(data, class_column='Attack', benign_label='Benign'):
    # Extract DDoS and benign samples
    ddos_samples = data[data[class_column] != benign_label]
    benign_samples = data[data[class_column] == benign_label]

    # Check for empty classes
    if len(benign_samples) == 0 or len(ddos_samples) == 0:
        print(f"Error: One of the classes has zero samples! Benign: {len(benign_samples)}, DDoS: {len(ddos_samples)}")
        return data

    # Always reduce the larger class to match the smaller class
    if len(benign_samples) > len(ddos_samples):
        print(f"Reducing Benign samples from {len(benign_samples)} to match DDoS count of {len(ddos_samples)}.")
        benign_samples = benign_samples.sample(n=len(ddos_samples), random_state=42)
    elif len(ddos_samples) > len(benign_samples):
        print(f"Reducing DDoS samples from {len(ddos_samples)} to match Benign count of {len(benign_samples)}.")
        ddos_samples = ddos_samples.sample(n=len(benign_samples), random_state=42)


    balanced_data = pd.concat([ddos_samples, benign_samples]).sample(frac=1, random_state=42).reset_index(drop=True)
    
    print(f"\n=== Balanced Dataset ===")
    print(balanced_data[class_column].value_counts())

    return balanced_data


def check_two_class(y, name):
    u = np.unique(np.asarray(y))
    if len(u) < 2:
        raise ValueError(f"{name} is single-class: {u}. Retry split (seed) / adjust split settings.")
    print(f"[OK] {name} has both classes:", u)


def balance_after_split(df, y_col="Attack", random_state=42):
    """
    IMPORTANT: balance AFTER splitting (train only).
    This avoids leaking the same IP-driven structure into both train/test.
    """
    df = df.copy()
    c1 = df[df[y_col] == 1]
    c0 = df[df[y_col] == 0]
    if len(c0) == 0 or len(c1) == 0:
        return df

    n = min(len(c0), len(c1))
    c0s = c0.sample(n=n, random_state=random_state)
    c1s = c1.sample(n=n, random_state=random_state)
    out = pd.concat([c0s, c1s], axis=0).sample(frac=1, random_state=random_state).reset_index(drop=True)
    return out

# %%
# --- put near your other utils ---
def save_fig(path, dpi=300):
    os.makedirs(os.path.dirname(path), exist_ok=True)
    plt.savefig(path, dpi=dpi, bbox_inches="tight")
    plt.show()
    plt.close()
    print(f"[saved] {path}")


def pad_and_reshape_features(X, window_size):
    """
    X: [batch, n_features] -> pad to multiple of window_size, then reshape to
       [batch, window_size, n_features_per_step]
    """
    X = np.asarray(X, dtype=np.float32)
    n = X.shape[1]
    pad = (window_size - (n % window_size)) % window_size
    if pad > 0:
        X = np.pad(X, ((0, 0), (0, pad)), mode="constant", constant_values=0.0)
    n_features_per_step = X.shape[1] // window_size
    return X.reshape(X.shape[0], window_size, n_features_per_step)



def run_shap_on_raw_no_pca(model, scaler, X_raw_sample, feature_names, window_size,
                           save_dir="shap_plots",
                           background_size=200,
                           max_display=20,
                           n_waterfalls=1):
    os.makedirs(save_dir, exist_ok=True)

    X_raw_sample = np.asarray(X_raw_sample, dtype=np.float32)
    m = min(background_size, X_raw_sample.shape[0])
    idx = np.random.default_rng(42).choice(X_raw_sample.shape[0], size=m, replace=False)
    bg = X_raw_sample[idx]

    def _predict_from_raw(X_raw):
        X_raw = np.asarray(X_raw, dtype=np.float32)
        Xs = scaler.transform(X_raw).astype(np.float32)
        Xseq = pad_and_reshape_features(Xs, window_size)
        return model.predict(Xseq, verbose=0).astype(np.float32)

    masker = shap.maskers.Independent(bg)
    explainer = shap.Explainer(_predict_from_raw, masker)
    shap_values = explainer(X_raw_sample)

    # Summary beeswarm
    plt.figure(figsize=(14, 10))
    shap.summary_plot(shap_values, X_raw_sample, feature_names=feature_names, show=False, max_display=max_display)
    plt.tight_layout()
    plt.savefig(os.path.join(save_dir, "shap_summary.png"), dpi=400, bbox_inches="tight")
    plt.close()

    # Summary bar
    plt.figure(figsize=(14, 10))
    shap.summary_plot(shap_values, X_raw_sample, feature_names=feature_names,
                      plot_type="bar", show=False, max_display=max_display)
    plt.tight_layout()
    plt.savefig(os.path.join(save_dir, "shap_summary_bar.png"), dpi=400, bbox_inches="tight")
    plt.close()

    # Waterfalls
    for i in range(min(n_waterfalls, X_raw_sample.shape[0])):
        plt.figure(figsize=(12, 8))
        shap.waterfall_plot(
            shap.Explanation(
                values=shap_values[i].values,
                base_values=shap_values.base_values[i],
                feature_names=feature_names,
                data=X_raw_sample[i]
            ),
            max_display=max_display,
            show=False
        )
        plt.tight_layout()
        plt.savefig(os.path.join(save_dir, f"shap_waterfall_{i}.png"), dpi=400, bbox_inches="tight")
        plt.close()

    return shap_values


def explain_with_lime_raw_no_pca(model, scaler, window_size,
                                 X_raw_sample, feature_names, class_names,
                                 save_path_prefix="lime_explanation",
                                 num_samples=5, random_state=42):
    import os
    from lime.lime_tabular import LimeTabularExplainer
    import numpy as np
    import pandas as pd

    os.makedirs(os.path.dirname(save_path_prefix), exist_ok=True)

    if isinstance(X_raw_sample, pd.DataFrame):
        X_np = X_raw_sample[feature_names].values.astype(np.float32)
    else:
        X_np = np.asarray(X_raw_sample, dtype=np.float32)

    def predict_from_raw_for_lime(X_raw_np):
        X_raw_np = np.asarray(X_raw_np, dtype=np.float32)
        Xs = scaler.transform(X_raw_np).astype(np.float32)
        Xseq = pad_and_reshape_features(Xs, window_size)
        p = model.predict(Xseq, verbose=0).astype(np.float32).ravel()
        return np.column_stack([1.0 - p, p])

    explainer = LimeTabularExplainer(
        training_data=X_np,
        feature_names=feature_names,
        class_names=class_names,
        mode="classification",
        discretize_continuous=True,
        random_state=random_state
    )

    rng = np.random.default_rng(random_state)
    idxs = rng.choice(X_np.shape[0], size=min(num_samples, X_np.shape[0]), replace=False)

    for idx in idxs:
        exp = explainer.explain_instance(
            data_row=X_np[idx],
            predict_fn=predict_from_raw_for_lime,
            num_features=min(10, len(feature_names))
        )
        html_path = f"{save_path_prefix}_sample_{idx}.html"
        exp.save_to_file(html_path)
        print(f"[saved] {html_path}")


def plot_and_save_history(history, y_test, y_pred, y_pred_prob, plots_dir):
    os.makedirs(plots_dir, exist_ok=True)
    keys = set(history.history.keys())
    if not {"loss","val_loss"} <= keys or not {"accuracy","val_accuracy"} <= keys:
        print("History missing expected keys; skipping plots.")
        return

    # Loss
    plt.figure(figsize=(8, 6))
    plt.plot(history.history['loss'], label='Training Loss', marker='o')
    plt.plot(history.history['val_loss'], label='Validation Loss', marker='o')
    plt.title('Model Loss Over Epochs'); plt.xlabel('Epochs'); plt.ylabel('Loss')
    plt.legend(); plt.grid(True, alpha=0.5); plt.tight_layout()
    save_fig(os.path.join(plots_dir, "loss_plot.png"))

    # Accuracy
    plt.figure(figsize=(8, 6))
    plt.plot(history.history['accuracy'], label='Training Accuracy', marker='o')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy', marker='o')
    plt.title('Model Accuracy Over Epochs'); plt.xlabel('Epochs'); plt.ylabel('Accuracy')
    plt.legend(); plt.grid(True, alpha=0.5); plt.tight_layout()
    save_fig(os.path.join(plots_dir, "accuracy_plot.png"))

    # Metrics to file
    from sklearn.metrics import precision_recall_fscore_support, roc_curve, auc, precision_recall_curve
    precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
    metrics_file_path = os.path.join(plots_dir, "evaluation_metrics.txt")
    with open(metrics_file_path, "w") as f:
        f.write(f"Precision: {precision:.6f}\nRecall: {recall:.6f}\nF1-Score: {f1:.6f}\n")
    print(f"[saved] {metrics_file_path}")

    # ROC
    fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
    roc_auc = auc(fpr, tpr)
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, label=f'ROC (AUC={roc_auc:.6f})')
    plt.plot([0, 1], [0, 1], linestyle='--', color='r', label='Random')
    plt.title('ROC Curve'); plt.xlabel('FPR'); plt.ylabel('TPR')
    plt.legend(); plt.grid(True, alpha=0.5); plt.tight_layout()
    save_fig(os.path.join(plots_dir, "roc_curve.png"))

    # PR curve
    precision_vals, recall_vals, _ = precision_recall_curve(y_test, y_pred_prob)
    plt.figure(figsize=(8, 6))
    plt.plot(recall_vals, precision_vals)
    plt.title('Precision-Recall Curve'); plt.xlabel('Recall'); plt.ylabel('Precision')
    plt.grid(True, alpha=0.5); plt.tight_layout()
    save_fig(os.path.join(plots_dir, "precision_recall_curve.png"))

    print(f"Precision={precision:.6f} Recall={recall:.6f} F1={f1:.6f} AUC={roc_auc:.6f}")

if "TransformerBlock" not in globals():
    @tf.keras.utils.register_keras_serializable(package="XNFT")
    class TransformerBlock(tf.keras.layers.Layer):
        def __init__(self, num_heads, ff_dim, input_dim=None, dropout_rate=0.1, **kwargs):
            super().__init__(**kwargs)
            self.num_heads = num_heads
            self.ff_dim = ff_dim
            self.input_dim_cfg = input_dim  # avoid clashing with Layer.input_dim
            self.dropout_rate = dropout_rate
    
            self.att = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=ff_dim)
            self.ffn = tf.keras.Sequential([
                tf.keras.layers.Dense(ff_dim, activation="relu"),
                tf.keras.layers.Dense(input_dim if input_dim else ff_dim)
            ])
            self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
            self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
            self.dropout1 = tf.keras.layers.Dropout(dropout_rate)
            self.dropout2 = tf.keras.layers.Dropout(dropout_rate)
    
        def call(self, inputs, training=None):
            if training is None:
                training = False
            attn_output = self.att(inputs, inputs)
            attn_output = self.dropout1(attn_output, training=training)
            out1 = self.layernorm1(inputs + attn_output)
            ffn_output = self.ffn(out1)
            ffn_output = self.dropout2(ffn_output, training=training)
            return self.layernorm2(out1 + ffn_output)
    
        def get_config(self):
            config = super().get_config()
            config.update({
                "num_heads": self.num_heads,
                "ff_dim": self.ff_dim,
                "input_dim": self.input_dim_cfg,
                "dropout_rate": self.dropout_rate,
            })
            return config
    
        @classmethod
        def from_config(cls, config):
            return cls(**config)
    

def build_flow_transformer(input_shape, num_heads, ff_dim, num_transformer_blocks, dropout_rate):
    inputs = tf.keras.Input(shape=input_shape, name="Flow_Input")
    x = inputs
    for _ in range(num_transformer_blocks):
        x = TransformerBlock(num_heads, ff_dim, input_dim=input_shape[-1], dropout_rate=dropout_rate)(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(64, activation="relu")(x)
    x = tf.keras.layers.Dropout(dropout_rate)(x)
    outputs = tf.keras.layers.Dense(1, activation="sigmoid", name="Binary_Output")(x)
    return tf.keras.Model(inputs=inputs, outputs=outputs)

### Hyperparameter Tuning ###


# def tune_hyperparameters(X_train, y_train, X_test, y_test, input_shape):
#     hyperparameter_grid = {
#         "num_heads": [2, 4, 8],
#         "ff_dim": [64, 128, 256],
#         "num_transformer_blocks": [2, 3, 4],
#         "dropout_rate": [0.1, 0.2, 0.3],
#         "learning_rate": [0.001, 0.0005, 0.0001],
#         "batch_size": [32, 64, 128]
#     }



# def tune_hyperparameters(X_train, y_train, X_test, y_test, input_shape):
#     hyperparameter_grid = {
#         "num_heads": [2, 4],
#         "ff_dim": [64],
#         "num_transformer_blocks": [2, 3],
#         "dropout_rate": [0.1],
#         "learning_rate": [0.0005],
#         "batch_size": [32]
#     }
# # esting: num_heads=2, ff_dim=64, num_transformer_blocks=2, dropout_rate=0.1, learning_rate=0.0005, batch_size=32
    
#     results = []  # To store results for each combination
#     best_auc = 0
#     best_params = None

#     for num_heads in hyperparameter_grid["num_heads"]:
#         for ff_dim in hyperparameter_grid["ff_dim"]:
#             for num_transformer_blocks in hyperparameter_grid["num_transformer_blocks"]:
#                 for dropout_rate in hyperparameter_grid["dropout_rate"]:
#                     for learning_rate in hyperparameter_grid["learning_rate"]:
#                         for batch_size in hyperparameter_grid["batch_size"]:
#                             print(f"Testing: num_heads={num_heads}, ff_dim={ff_dim}, num_transformer_blocks={num_transformer_blocks}, dropout_rate={dropout_rate}, learning_rate={learning_rate}, batch_size={batch_size}")

#                             model = build_flow_transformer(input_shape, num_heads, ff_dim, num_transformer_blocks, dropout_rate)
#                             base_optimizer = Adam(learning_rate=learning_rate)
#                             optimizer = LossScaleOptimizer(base_optimizer)
#                             model.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy", tf.keras.metrics.AUC(name="auc")])
                           
#                             early_stopping = EarlyStopping(
#                                 monitor="val_auc",
#                                 patience=1, mode="max",
#                                 restore_best_weights=True
#                             )

#                             history = model.fit(
#                                 X_train, y_train,
#                                 batch_size=batch_size,
#                                 epochs=5,  # Fixed epochs for tuning
#                                 validation_data=(X_test, y_test),
#                                 callbacks=[early_stopping],
#                                 verbose=0
#                             )

#                             # y_pred = (model.predict(X_test) > 0.5).astype(int)
#                             # auc_score = roc_auc_score(y_test, y_pred)

#                             # y_prob = model.predict(X_test, verbose=0).ravel()
#                             # auc_score = roc_auc_score(y_test, y_prob)
                            
#                             # accuracy = history.history['val_accuracy'][-1]

#                             auc_score = float(np.max(history.history.get("val_auc", [0.0])))
#                             accuracy  = float(np.max(history.history.get("val_accuracy", [0.0])))


#                             # Append results to the list
#                             results.append({
#                                 "num_heads": num_heads,
#                                 "ff_dim": ff_dim,
#                                 "num_transformer_blocks": num_transformer_blocks,
#                                 "dropout_rate": dropout_rate,
#                                 "learning_rate": learning_rate,
#                                 "batch_size": batch_size,
#                                 "AUC": auc_score,
#                                 "Accuracy": accuracy
#                             })

#                             if auc_score > best_auc:
#                                 best_auc = auc_score
#                                 best_params = {
#                                     "num_heads": num_heads,
#                                     "ff_dim": ff_dim,
#                                     "num_transformer_blocks": num_transformer_blocks,
#                                     "dropout_rate": dropout_rate,
#                                     "learning_rate": learning_rate,
#                                     "batch_size": batch_size
#                                 }
#                             print(f"AUC: {auc_score:.6f}, Best AUC so far: {best_auc:.6f}")

#     # Convert results to a pandas DataFrame for better readability
#     results_df = pd.DataFrame(results)

#     # Printing the results to the console
#     print("\n=== Hyperparameter Tuning Results ===")
#     print(results_df)

#     # Save the DataFrame to a text file
#     results_txt_path = os.path.join(plots_dir, "Hyperparameter_Results.txt")
#     results_df.to_csv(results_txt_path, sep="\t", index=False)

#     print(f"Hyperparameter tuning results saved to: {results_txt_path}")
#     print("Available history keys:", history.history.keys())
    
#     print("Best Hyperparameters:", best_params)

#     return best_params, results_df



def tune_hyperparameters(
    X_train, y_train,
    X_val, y_val,
    input_shape,
    n_trials=25,          # 🔴 control speed here (20–30 is ideal)
    seed=42
):
    rng = np.random.default_rng(seed)

    # 🔹 Full paper-justified ranges
    search_space = {
        "num_heads": [2, 4, 8],
        "ff_dim": [64, 128, 256],
        "num_transformer_blocks": [2, 3, 4],
        "dropout_rate": [0.1, 0.2, 0.3],
        "learning_rate": [0.001, 0.0005, 0.0001],
        "batch_size": [32, 64, 128]
    }

    results = []
    best_auc = -1.0
    best_params = None

    for trial in range(n_trials):
        # 🔹 Randomly sample one configuration
        params = {k: rng.choice(v) for k, v in search_space.items()}

        print(f"\n[Trial {trial+1}/{n_trials}] Params: {params}")

        model = build_flow_transformer(
            input_shape=input_shape,
            num_heads=params["num_heads"],
            ff_dim=params["ff_dim"],
            num_transformer_blocks=params["num_transformer_blocks"],
            dropout_rate=params["dropout_rate"]
        )

        optimizer = LossScaleOptimizer(
            Adam(learning_rate=params["learning_rate"])
        )

        model.compile(
            optimizer=optimizer,
            loss="binary_crossentropy",
            metrics=[
                "accuracy",
                tf.keras.metrics.AUC(name="auc")
            ]
        )

        early_stopping = EarlyStopping(
            monitor="val_auc",
            mode="max",
            patience=2,
            restore_best_weights=True
        )

        history = model.fit(
            X_train, y_train,
            validation_data=(X_val, y_val),
            epochs=10,                     # 🔴 cheap tuning epochs
            batch_size=params["batch_size"],
            callbacks=[early_stopping],
            verbose=0
        )

        auc_score = float(np.max(history.history.get("val_auc", [0.0])))
        acc_score = float(np.max(history.history.get("val_accuracy", [0.0])))

        results.append({**params, "AUC": auc_score, "Accuracy": acc_score})

        if auc_score > best_auc:
            best_auc = auc_score
            best_params = params

        print(f"→ Val AUC: {auc_score:.5f} | Best so far: {best_auc:.5f}")

        tf.keras.backend.clear_session()  # 🔴 important for GPU memory

    results_df = pd.DataFrame(results)
    results_df.to_csv(
        os.path.join(plots_dir, "Hyperparameter_Results.txt"),
        sep="\t",
        index=False
    )

    print("\n=== Random Search Summary ===")
    print(results_df.sort_values("AUC", ascending=False).head())
    print("\nBest Hyperparameters:", best_params)

    return best_params, results_df



def visualize_model_structure(model, save_path="model_structure.png"):
    """
    Visualizes the structure of the Transformer model and saves it to a file.

    Args:
        model (tf.keras.Model): The Transformer model to visualize.
        save_path (str): Path to save the visualization.
    """
    # Generate and save the model plot
    plot_model(
        model,
        to_file=save_path,
        show_shapes=True,
        show_layer_names=True,
        rankdir="TB",  # Top-to-Bottom layout
        dpi=400
    )
    plt.show()
    print(f"Model structure diagram saved to {save_path}")
    
    # Print the model summary to the console
    print("\nModel Summary:")
    model.summary()  # Print summary directly for better readability in console

    
# --- timing utils ---
def measure_training_time(model, fit_kwargs):
    t0 = time.perf_counter()
    hist = model.fit(**fit_kwargs)
    t1 = time.perf_counter()
    return hist, (t1 - t0)  # seconds


def measure_eval_time(model, X, y, batch_size=128):
    t0 = time.perf_counter()
    _ = model.evaluate(X, y, batch_size=batch_size, verbose=0)
    t1 = time.perf_counter()
    return (t1 - t0)  # seconds


def _dir_size_mb(path):
    total = 0
    for root, _, files in os.walk(path):
        for f in files:
            total += os.path.getsize(os.path.join(root, f))
    return round(total / (1024**2), 3)

def measure_model_size(model, out_dir="model_artifacts"):
    os.makedirs(out_dir, exist_ok=True)

    # SavedModel
    sm_dir = os.path.join(out_dir, "savedmodel")
    if os.path.exists(sm_dir):
        import shutil; shutil.rmtree(sm_dir)
    model.save(sm_dir, include_optimizer=False)
    savedmodel_mb = _dir_size_mb(sm_dir)

    # H5
    h5_path = os.path.join(out_dir, "model.h5")
    model.save(h5_path, include_optimizer=False)
    h5_mb = round(os.path.getsize(h5_path) / (1024**2), 3)

    return {
        "savedmodel_path": sm_dir,
        "savedmodel_mb": savedmodel_mb,
        "h5_path": h5_path,
        "h5_mb": h5_mb,
        "trainable_params": int(model.count_params())
    }


def measure_inference_time(model, X_ref, batch_size=1, repeats=30, warmup=5, device=None):
    """
    Returns median per-sample latency (ms) and median per-batch latency (ms).
    """
    Xb = X_ref[:batch_size].astype(np.float32)
    ctx = tf.device(device) if device else nullcontext()

    with ctx:
        # warmup
        for _ in range(warmup):
            _ = model.predict(Xb, batch_size=batch_size, verbose=0)

        times = []
        for _ in range(repeats):
            t0 = time.perf_counter()
            _ = model.predict(Xb, batch_size=batch_size, verbose=0)
            t1 = time.perf_counter()
            times.append(t1 - t0)

    times = np.array(times)
    batch_p50_ms = np.percentile(times, 50) * 1000.0
    per_sample_p50_ms = batch_p50_ms / batch_size
    return {
        "device": device or "default",
        "batch_size": batch_size,
        "batch_latency_p50_ms": round(batch_p50_ms, 3),
        "per_sample_latency_p50_ms": round(per_sample_p50_ms, 3),
    }

# %%
def graph_based_flow_splitting(
    data,
    class_column="Attack",
    src_col="IPV4_SRC_ADDR",
    dst_col="IPV4_DST_ADDR",
    test_fraction=0.2,
    random_state=42,
    strict=True,          # keep only intra-split flows to avoid leakage
    make_plot=True
):
    """
    Graph-based split on IP nodes with leakage-safe flow assignment.

    Fixes:
    1) Node labels are aggregated (attack-dominant) instead of overwritten.
    2) Train/Test flows are disjoint:
       - train if (src AND dst) in train_nodes
       - test  if (src AND dst) in test_nodes
       - cross-split flows are dropped when strict=True
    """

    # --- Build graph (connectivity only) ---
    G = nx.Graph()
    edges = data[[src_col, dst_col]].dropna().values
    G.add_edges_from(edges)
    print(f"Graph created with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges.")

    # --- Aggregate node labels (attack-dominant) ---
    # Assumes Attack already encoded to 0/1 (Benign=0, DDoS=1)
    node_label = {n: 0 for n in G.nodes()}
    for s, d, y in data[[src_col, dst_col, class_column]].dropna().itertuples(index=False, name=None):
        if int(y) == 1:              # any DDoS incident => node is DDoS
            node_label[s] = 1
            node_label[d] = 1

    benign_count = sum(1 for v in node_label.values() if v == 0)
    ddos_count   = sum(1 for v in node_label.values() if v == 1)
    print(f"Benign nodes: {benign_count}, DDoS nodes: {ddos_count}")
    if ddos_count == 0:
        raise ValueError("No DDoS nodes found after aggregation. Check label encoding.")

    node_list  = np.array(list(node_label.keys()))
    label_list = np.array([node_label[n] for n in node_list])

    # --- Stratified split on nodes ---
    train_nodes, test_nodes = train_test_split(
        node_list,
        test_size=test_fraction,
        stratify=label_list,
        random_state=random_state
    )
    train_nodes = set(train_nodes)
    test_nodes  = set(test_nodes)
    print(f"Train nodes: {len(train_nodes)}, Test nodes: {len(test_nodes)}")

    # --- Leakage-safe flow assignment ---
    src = data[src_col]
    dst = data[dst_col]

    in_train_src = src.isin(train_nodes)
    in_train_dst = dst.isin(train_nodes)
    in_test_src  = src.isin(test_nodes)
    in_test_dst  = dst.isin(test_nodes)

    if strict:
        train_mask = in_train_src & in_train_dst
        test_mask  = in_test_src  & in_test_dst
        cross_mask = (in_train_src & in_test_dst) | (in_test_src & in_train_dst)
        dropped = int(cross_mask.sum())
    else:
        # Not recommended for leakage claims; kept for debugging only.
        train_mask = in_train_src | in_train_dst
        test_mask  = in_test_src  | in_test_dst
        dropped = int((train_mask & test_mask).sum())

    train_data = data[train_mask].copy()
    test_data  = data[test_mask].copy()

    # --- Sanity checks ---
    assert set(train_data.index).isdisjoint(set(test_data.index)), "Row overlap between train/test!"
    assert train_nodes.isdisjoint(test_nodes), "Node overlap between train/test!"

    print("\n=== Train Set Label Distribution ===")
    print(train_data[class_column].value_counts())
    print("\n=== Test Set Label Distribution ===")
    print(test_data[class_column].value_counts())
    print(f"\nDropped cross-split flows (strict={strict}): {dropped}")

    # --- Optional visualization (small graphs only; otherwise heavy) ---
    if make_plot:
        try:
            # Sample nodes for plotting if huge
            max_nodes_plot = 3000
            H = G
            if G.number_of_nodes() > max_nodes_plot:
                sampled_nodes = list(np.random.default_rng(random_state).choice(
                    list(G.nodes()), size=max_nodes_plot, replace=False
                ))
                H = G.subgraph(sampled_nodes).copy()

            # color by node_label
            node_labels_H = {n: node_label.get(n, 0) for n in H.nodes()}
            color_map = ["red" if node_labels_H[n] == 1 else "green" for n in H.nodes()]
            size_map  = [120 if node_labels_H[n] == 1 else 40 for n in H.nodes()]

            pos = nx.spring_layout(H, seed=random_state, k=0.15, iterations=50)
            plt.figure(figsize=(12, 12))
            nx.draw_networkx_edges(H, pos, alpha=0.25, edge_color="gray")
            nx.draw_networkx_nodes(H, pos, node_color=color_map, node_size=size_map, alpha=0.9)
            plt.title("Graph-Based Flow Visualization (sampled if large)")
            plt.axis("off")
            save_path = os.path.join(plots_dir, "graph_publication.png")
            plt.tight_layout()
            plt.savefig(save_path, dpi=300, bbox_inches="tight")
            plt.show()
            plt.close()
            print(f"Graph visualization saved to {save_path}.")
        except Exception as e:
            print(f"[warn] graph plot skipped: {e}")

    return train_data, test_data, {"dropped_cross_flows": dropped}

def graph_split_with_retries(
    data_enc,
    label_col="Attack",
    src_col="IPV4_SRC_ADDR",
    dst_col="IPV4_DST_ADDR",
    test_fraction=0.2,
    strict=True,
    seed_start=42,
    n_tries=20,
    min_test_flows=10000,
    min_test_ddos=500,
    make_plot_final=True
):
    """
    Tries multiple random seeds until:
      - test has BOTH classes
      - test is not tiny
      - test has enough DDoS samples
    """
    best = None
    best_score = -1

    for seed in range(seed_start, seed_start + n_tries):
        print(f"\n--- Graph split try seed={seed} ---")
        train_df, test_df, info = graph_based_flow_splitting(
            data_enc,
            class_column=label_col,
            src_col=src_col,
            dst_col=dst_col,
            test_fraction=test_fraction,
            random_state=seed,
            strict=strict,
            make_plot=False
        )

        vc = test_df[label_col].value_counts().to_dict()
        test_total = len(test_df)
        test_ddos  = int(vc.get(1, 0))
        test_ben   = int(vc.get(0, 0))

        ok = (test_total >= min_test_flows) and (test_ddos >= min_test_ddos) and (test_ben > 0)
        print(f"seed={seed} test_flows={test_total} (benign={test_ben}, ddos={test_ddos}) ok={ok}")

        score = test_ddos * 10 + test_total
        if score > best_score:
            best_score = score
            best = (seed, train_df, test_df, info)

        if ok:
            # final split with plot enabled
            if make_plot_final:
                train_df, test_df, info = graph_based_flow_splitting(
                    data_enc,
                    class_column=label_col,
                    src_col=src_col,
                    dst_col=dst_col,
                    test_fraction=test_fraction,
                    random_state=seed,
                    strict=strict,
                    make_plot=True
                )
            return seed, train_df, test_df, info

    print("[WARN] No seed met thresholds. Using best available split.")
    seed, train_df, test_df, info = best
    if make_plot_final:
        train_df, test_df, info = graph_based_flow_splitting(
            data_enc,
            class_column=label_col,
            src_col=src_col,
            dst_col=dst_col,
            test_fraction=test_fraction,
            random_state=seed,
            strict=strict,
            make_plot=True
        )
    return seed, train_df, test_df, info

# %%
import pandas as pd

# def load_data(file_path, sample_fraction=1, chunksize=1_000_000):
#     chunks = []
    
#     for chunk in pd.read_csv(file_path, chunksize=chunksize):
#         filtered = chunk[chunk['Attack'].isin(['Benign', 'DDoS'])]
#         chunks.append(filtered)
  
#     df = pd.concat(chunks, ignore_index=True)

#     print("\n=== Missing Values ===")
#     print(df.isnull().sum())
#     print("\n=== Label Distribution ===")
#     print(df['Attack'].value_counts())
    
#     return df


def load_data(file_path, chunksize=1_000_000):
    chunks = []
    for chunk in pd.read_csv(file_path, chunksize=chunksize):
        chunk = chunk[chunk["Attack"].notna()].copy()
        # keep benign and ANY ddos-like label (or any non-benign if you want binary)
        chunk = chunk[chunk["Attack"].isin(["Benign", "ddos"])].copy()

        # normalize to two-class label
        chunk["Attack"] = chunk["Attack"].apply(lambda x: "Benign" if x == "Benign" else "DDoS")
        chunks.append(chunk)

    df = pd.concat(chunks, ignore_index=True)
    print(df["Attack"].value_counts())
    return df

# %%
with tf.device('/GPU:0'):
# Main Function
    def main(sample_fraction=1):
        file_path = "/home/g_kirubavathi/Amal/1_XNFT_R1/R2/NF-ToN-IoT.csv"
        # data = pd.read_csv(file_path)
        # print(data['Attack'].value_counts())
        data = load_data(file_path)
        
        print("NF-ToN-IoT.csv")
    
        if sample_fraction < 1.0:
            data = data.sample(frac=sample_fraction, random_state=42)
            label_col = "Attack"
            print("After sampling:", data.shape)
            print("Label counts after sampling:\n", data[label_col].value_counts())
    
       

        # Keep raw IP strings for graph splitting; NEVER use IPs as features
        src_col = "IPV4_SRC_ADDR"
        dst_col = "IPV4_DST_ADDR"
        label_col = "Attack"
        
        # Only encode label (Attack) here; do NOT encode IPs
        categorical_columns = [label_col]   # <-- changed
        
        # Define feature columns BEFORE encoding anything else:
        DROP_COLS = [label_col, src_col, dst_col, "Label"]
        feature_columns = [
            c for c in data.columns
            if c not in DROP_COLS and pd.api.types.is_numeric_dtype(data[c])
        ]
        print("Num features (excluding label+IPs):", len(feature_columns))


        # -------------------------------
        # Reviewer-driven feature removal
        # -------------------------------
        EXCLUDE_FEATURES = {
            "DNS_QUERY_ID",
            "DNS_TTL_ANSWER", "MIN_TTL", "MAX_TTL", "DNS_QUERY_TYPE",                 
        }
        
        feature_columns = [c for c in feature_columns if c not in EXCLUDE_FEATURES]
        
        print("Removed features:", sorted(EXCLUDE_FEATURES))
        print("Num features after removal:", len(feature_columns))
    
        class_names = ["Benign", "DDoS"]

        # -------------------------------
        # 1) Encode label FIRST (do NOT balance yet)
        # -------------------------------
        data_enc = encode_attack_label(data, label_col=label_col, benign_label="Benign")
        check_two_class(data_enc[label_col].values, "FULL CIC (encoded)")
        
        # -------------------------------
        # 2) Graph split with retries (avoids single-class / tiny test)
        # -------------------------------
        seed_used, train_data, test_data, split_info = graph_split_with_retries(
            data_enc,
            label_col=label_col,
            src_col=src_col,
            dst_col=dst_col,
            test_fraction=0.2,
            strict=True,
            seed_start=42,
            n_tries=20,
            min_test_flows=10000,
            min_test_ddos=500,
            make_plot_final=True
        )
        print("Split info:", split_info)
        print("Seed used:", seed_used)
        total_flows = len(data_enc)
        dropped = split_info.get("dropped_cross_flows", 0)
        print(f"Dropped cross flows: {dropped} ({100*dropped/total_flows:.2f}%) out of {total_flows}")

        
        # -------------------------------
        # 3) Balance ONLY TRAIN (recommended)
        #    Keep test unbalanced for realism
        # -------------------------------
        train_data = balance_after_split(train_data, y_col=label_col, random_state=seed_used)
        print("\n[Train balanced] label counts:")
        print(train_data[label_col].value_counts())
        
        # -------------------------------
        # 4) Final sanity checks
        # -------------------------------
        check_two_class(train_data[label_col].values, "Train (after balancing)")
        check_two_class(test_data[label_col].values, "Test")





        
                # -------------------------------
        # 3.5) Create VALIDATION split from TRAIN only (fix test leakage)
        # -------------------------------
        train_inner, val_inner = train_test_split(
            train_data,
            test_size=0.2,
            stratify=train_data[label_col],
            random_state=seed_used
        )
        
        print("\n[TrainInner] label counts:")
        print(train_inner[label_col].value_counts())
        print("\n[ValInner] label counts:")
        print(val_inner[label_col].value_counts())
        
        check_two_class(train_inner[label_col].values, "TrainInner")
        check_two_class(val_inner[label_col].values, "ValInner")





        

        
        # # Feature Selection and Label Extraction
        # X_train, y_train = train_data[feature_columns], train_data['Attack']
        # X_test, y_test = test_data[feature_columns], test_data['Attack']

        # Feature Extraction: TrainInner / ValInner / Test
        X_train = train_inner[feature_columns]; y_train = train_inner[label_col].values
        X_val   = val_inner[feature_columns];   y_val   = val_inner[label_col].values
        X_test  = test_data[feature_columns];   y_test  = test_data[label_col].values


        print("y_train unique:", np.unique(y_train))
        print("y_test unique :", np.unique(y_test))
    
       #  # Clean Dataset
       #  X_train_cleaned = clean_dataset(X_train)
       #  X_test_cleaned = clean_dataset(X_test)
    
       # # -------------------------------
       #  # Scale ONLY (no PCA)
       #  # -------------------------------
       #  scaler = StandardScaler()
       #  X_train_scaled = scaler.fit_transform(X_train_cleaned).astype(np.float32)
       #  X_test_scaled  = scaler.transform(X_test_cleaned).astype(np.float32)


       #  window_size = 5
       #  X_train_seq = pad_and_reshape_features(X_train_scaled, window_size)
       #  X_test_seq  = pad_and_reshape_features(X_test_scaled,  window_size)
        
       #  print("Scaled+Seq shapes:", X_train_seq.shape, X_test_seq.shape)




        X_train_cleaned = clean_dataset(X_train)
        X_val_cleaned   = clean_dataset(X_val)
        X_test_cleaned  = clean_dataset(X_test)
        
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train_cleaned).astype(np.float32)
        X_val_scaled   = scaler.transform(X_val_cleaned).astype(np.float32)
        X_test_scaled  = scaler.transform(X_test_cleaned).astype(np.float32)
        
        window_size = 5
        X_train_seq = pad_and_reshape_features(X_train_scaled, window_size)
        X_val_seq   = pad_and_reshape_features(X_val_scaled,   window_size)
        X_test_seq  = pad_and_reshape_features(X_test_scaled,  window_size)
        
        print("Scaled+Seq shapes:", X_train_seq.shape, X_val_seq.shape, X_test_seq.shape)







        n_feats = X_train_scaled.shape[1]
        pad = (window_size - (n_feats % window_size)) % window_size
        print(f"n_features={n_feats}, window_size={window_size}, pad={pad}, per_step={(n_feats+pad)//window_size}")
                
                
        # Hyperparameter Tuning
        try:
            # Hyperparameter tuning
            best_params, tuning_results = tune_hyperparameters(X_train_seq, y_train, X_val_seq, y_val, input_shape=X_train_seq.shape[1:])
            print("Best parameters found:", best_params)
        except Exception as e:
            print(f"Error during hyperparameter tuning: {e}")
            return
        
        # Build and train final model using PCA features
        model = build_flow_transformer(
            input_shape=X_train_seq.shape[1:],
            num_heads=best_params["num_heads"],
            ff_dim=best_params["ff_dim"],
            num_transformer_blocks=best_params["num_transformer_blocks"],
            dropout_rate=best_params["dropout_rate"]
        )
        
        # Visualize and save the model structure
        visualize_model_structure(model, save_path=os.path.join(plots_dir, "transformer_model_structure.png"))
        
        optimizer=LossScaleOptimizer(Adam(learning_rate=best_params["learning_rate"]))
        
        model.compile(
            optimizer=optimizer,
            loss="binary_crossentropy",
            metrics=["accuracy", tf.keras.metrics.AUC(name="auc")]
        )
        
        early_stopping = EarlyStopping(
            monitor="val_auc",
            mode="max",
            patience=5,
            restore_best_weights=True
        )

        print("Sanity check:")
        print("  X_train_seq:", X_train_seq.shape)
        print("  y_train:", len(y_train))
        print("  X_test_seq:", X_test_seq.shape)
        print("  y_test:", len(y_test))
        print("  X_val_seq:", X_val_seq.shape)
        print("  y_val:", len(y_val))
        
        assert X_val_seq.shape[0] == len(y_val), "Mismatch: X_val vs y_val"        
        assert X_train_seq.shape[0] == len(y_train), "Mismatch: X_train vs y_train"
        assert X_test_seq.shape[0]  == len(y_test),  "Mismatch: X_test vs y_test"

        print("SHAPES:")
        print("  train_data:", train_data.shape, " test_data:", test_data.shape)
        print("  X_train_cleaned:", X_train_cleaned.shape, " y_train:", len(y_train))
        print("  X_test_cleaned:",  X_test_cleaned.shape,  " y_test:",  len(y_test))
        print("  X_train_seq:", X_train_seq.shape, " X_test_seq:", X_test_seq.shape)
        assert X_train_seq.shape[0] == len(y_train)
        assert X_test_seq.shape[0]  == len(y_test)
            

                # --- TRAIN with timing ---
        fit_kwargs = dict(
            x=X_train_seq, y=y_train,
            batch_size=best_params["batch_size"],
            epochs=50,
            validation_data=(X_val_seq, y_val),
            callbacks=[early_stopping],
            verbose=1
        )
        history, train_time_s = measure_training_time(model, fit_kwargs)
        
            # --- EVALUATE timing ---
        eval_time_s = measure_eval_time(model, X_test_seq, y_test, batch_size=best_params["batch_size"])

        # --- PREDICTIONS (probabilities) ---
        y_pred_prob = model.predict(X_test_seq)
        y_pred = (y_pred_prob > 0.5).astype(int)
        
        print("ROC AUC Score:", roc_auc_score(y_test, y_pred_prob.ravel()))
        print("Classification Report:\n", classification_report(y_test, y_pred))
                
        # Updated Call to Plot and Save History with PCA data
        plot_and_save_history(history, y_test, y_pred, y_pred_prob, plots_dir)    

        cm = confusion_matrix(y_test, y_pred)
        plt.figure(figsize=(8, 6))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=["Benign", "DDoS"], yticklabels=["Benign", "DDoS"])
        plt.xlabel('Predicted'); plt.ylabel('True'); plt.title('Confusion Matrix'); plt.tight_layout()
        save_fig(os.path.join(plots_dir, "confusion_matrix.png"))
        print("Confusion Matrix:\n", cm)

        # --- MODEL SIZE ---
        sizes = measure_model_size(model, out_dir=os.path.join(plots_dir, "bench_min"))
        print(f"Params: {sizes['trainable_params']:,}")
        print(f"Model size — SavedModel: {sizes['savedmodel_mb']} MB, H5: {sizes['h5_mb']} MB")
        
        # --- INFERENCE LATENCY (bs=1, CPU and GPU if present) ---
        lat_cpu = measure_inference_time(model, X_test_seq, batch_size=1, repeats=30, warmup=5, device="/CPU:0")
        print(f"CPU bs=1 → per-sample p50: {lat_cpu['per_sample_latency_p50_ms']} ms")
        
        if tf.config.list_physical_devices('GPU'):
            lat_gpu = measure_inference_time(model, X_test_seq, batch_size=1, repeats=30, warmup=5, device="/GPU:0")
            print(f"GPU bs=1 → per-sample p50: {lat_gpu['per_sample_latency_p50_ms']} ms")
        
        # --- PAPER-STYLE TABLE ROW ---
        timing_row = {
            "Dataset": "NF-ToN-IoT.csv",
            "Training Time (s)": round(train_time_s, 2),
            "Evaluation Time (s)": round(eval_time_s, 2),
            "Avg Inference Time (ms)": lat_cpu["per_sample_latency_p50_ms"],
            "Max / Min Inference (ms)": "— / —"  # fill if you want max/min with a loop
        }
        timing_csv = os.path.join(plots_dir, "timings", "timing_summary.csv")
        os.makedirs(os.path.dirname(timing_csv), exist_ok=True)
        (pd.DataFrame([timing_row])).to_csv(timing_csv, index=False)
        print(f"[saved] {timing_csv}")

    
        X_raw_sample = X_test_cleaned.sample(n=min(200, len(X_test_cleaned)), random_state=42).values
        run_shap_on_raw_no_pca(model, scaler, X_raw_sample, feature_columns, window_size,
                               save_dir=os.path.join(plots_dir, "shap"),
                               background_size=200, max_display=12, n_waterfalls=1)
        
        explain_with_lime_raw_no_pca(
            model=model,
            scaler=scaler,
            window_size=window_size,
            X_raw_sample=X_test_cleaned,
            feature_names=feature_columns,
            class_names=["Benign", "DDoS"],
            save_path_prefix=os.path.join(plots_dir, "lime", "lime_explanation"),
            num_samples=10
        )
                

        print("Dataset: NF-ToN-IoT.csv")

        return {
        "model": model,
        "scaler": scaler,
        "window_size": window_size,
        "feature_columns": feature_columns
        }
# Out:
# 2026-02-07 13:27:03.691595: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-07 13:27:05.012807: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13195 MB memory:  -> device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 0000:3b:00.0, compute capability: 7.0

# %%
with tf.device('/GPU:0'):
    out = main(sample_fraction=0.5)
    model = out["model"]
    scaler = out["scaler"]
    window_size = out["window_size"]
    feature_columns = out["feature_columns"]
# Out:
# Attack
# DDoS      326345
# Benign    270279
# Name: count, dtype: int64
# NF-ToN-IoT.csv
# After sampling: (298312, 14)
# Label counts after sampling:
#  Attack
# DDoS      163285
# Benign    135027
# Name: count, dtype: int64
# Num features (excluding label+IPs): 10
# Removed features: ['DNS_QUERY_ID', 'DNS_QUERY_TYPE', 'DNS_TTL_ANSWER', 'MAX_TTL', 'MIN_TTL']
# Num features after removal: 10
# [OK] FULL CIC (encoded) has both classes: [0 1]
#
# --- Graph split try seed=42 ---
# Graph created with 1191 nodes and 1348 edges.
# Benign nodes: 1172, DDoS nodes: 19
# Train nodes: 952, Test nodes: 239
#
# === Train Set Label Distribution ===
# Attack
# 1    163105
# 0    124863
# Name: count, dtype: int64
#
# === Test Set Label Distribution ===
# Attack
# 0    66
# Name: count, dtype: int64
#
# Dropped cross-split flows (strict=True): 10278
# seed=42 test_flows=66 (benign=66, ddos=0) ok=False
#
# --- Graph split try seed=43 ---
# Graph created with 1191 nodes and 1348 edges.
# Benign nodes: 1172, DDoS nodes: 19
# Train nodes: 952, Test nodes: 239
#
# === Train Set Label Distribution ===
# Attack
# 1    133091
# 0    100854
# Name: count, dtype: int64
#
# === Test Set Label Distribution ===
# Attack
# 0    1728
# Name: count, dtype: int64
#
# Dropped cross-split flows (strict=True): 62639
# seed=43 test_flows=1728 (benign=1728, ddos=0) ok=False
#
# --- Graph split try seed=44 ---
# Graph created with 1191 nodes and 1348 edges.
# Benign nodes: 1172, DDoS nodes: 19
# Train nodes: 952, Test nodes: 239
#
# === Train Set Label Distribution ===
# Attack
# 1    85995
# 0    81781
# Name: count, dtype: int64
#
# === Test Set Label Distribution ===
# Attack
# 0    725
# 1    126
# Name: count, dtype: int64
#
# Dropped cross-split flows (strict=True): 129685
# seed=44 test_flows=851 (benign=725, ddos=126) ok=False
#
# --- Graph split try seed=45 ---
# Graph created with 1191 nodes and 1348 edges.
# Benign nodes: 1172, DDoS nodes: 19
# Train nodes: 952, Test nodes: 239
#
# === Train Set Label Distribution ===
# Attack
# 0    90748
# 1    82196
# Name: count, dtype: int64
#
# === Test Set Label Distribution ===
# Attack
# 1    8903
# 0    4855
# Name: count, dtype: int64
#
# Dropped cross-split flows (strict=True): 111610
# seed=45 test_flows=13758 (benign=4855, ddos=8903) ok=True
# Graph created with 1191 nodes and 1348 edges.
# Benign nodes: 1172, DDoS nodes: 19
# Train nodes: 952, Test nodes: 239
#
# === Train Set Label Distribution ===
# Attack
# 0    90748
# 1    82196
# Name: count, dtype: int64
#
# === Test Set Label Distribution ===
# Attack
# 1    8903
# 0    4855
# Name: count, dtype: int64
#
# Dropped cross-split flows (strict=True): 111610
# Graph visualization saved to /home/g_kirubavathi/Amal/1_XNFT_R1/R2/plots_r2_NF-CSE-CIC-IDS2018./graph_publication.png.
# Split info: {'dropped_cross_flows': 111610}
# Seed used: 45
# Dropped cross flows: 111610 (37.41%) out of 298312
#
# [Train balanced] label counts:
# Attack
# 0    82196
# 1    82196
# Name: count, dtype: int64
# [OK] Train (after balancing) has both classes: [0 1]
# [OK] Test has both classes: [0 1]
#
# [TrainInner] label counts:
# Attack
# 0    65757
# 1    65756
# Name: count, dtype: int64
#
# [ValInner] label counts:
# Attack
# 1    16440
# 0    16439
# Name: count, dtype: int64
# [OK] TrainInner has both classes: [0 1]
# [OK] ValInner has both classes: [0 1]
# y_train unique: [0 1]
# y_test unique : [0 1]
# Dataset successfully cleaned and prepared.
# Dataset successfully cleaned and prepared.
# Dataset successfully cleaned and prepared.
# Scaled+Seq shapes: (131513, 5, 2) (32879, 5, 2) (13758, 5, 2)
# n_features=10, window_size=5, pad=0, per_step=2
#
# [Trial 1/25] Params: {'num_heads': 2, 'ff_dim': 256, 'num_transformer_blocks': 3, 'dropout_rate': 0.2, 'learning_rate': 0.0005, 'batch_size': 128}
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# → Val AUC: 0.95599 | Best so far: 0.95599
#
# [Trial 2/25] Params: {'num_heads': 2, 'ff_dim': 256, 'num_transformer_blocks': 2, 'dropout_rate': 0.1, 'learning_rate': 0.0005, 'batch_size': 128}
# → Val AUC: 0.93115 | Best so far: 0.95599
#
# [Trial 3/25] Params: {'num_heads': 8, 'ff_dim': 256, 'num_transformer_blocks': 4, 'dropout_rate': 0.3, 'learning_rate': 0.0005, 'batch_size': 32}
# → Val AUC: 0.95817 | Best so far: 0.95817
#
# [Trial 4/25] Params: {'num_heads': 8, 'ff_dim': 128, 'num_transformer_blocks': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 128}
# → Val AUC: 0.97118 | Best so far: 0.97118
#
# [Trial 5/25] Params: {'num_heads': 8, 'ff_dim': 128, 'num_transformer_blocks': 3, 'dropout_rate': 0.3, 'learning_rate': 0.0005, 'batch_size': 64}
# → Val AUC: 0.96357 | Best so far: 0.97118
#
# [Trial 6/25] Params: {'num_heads': 4, 'ff_dim': 64, 'num_transformer_blocks': 2, 'dropout_rate': 0.2, 'learning_rate': 0.0001, 'batch_size': 32}
# → Val AUC: 0.95379 | Best so far: 0.97118
#
# [Trial 7/25] Params: {'num_heads': 8, 'ff_dim': 256, 'num_transformer_blocks': 2, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 128}
# → Val AUC: 0.96504 | Best so far: 0.97118
#
# [Trial 8/25] Params: {'num_heads': 8, 'ff_dim': 128, 'num_transformer_blocks': 2, 'dropout_rate': 0.3, 'learning_rate': 0.0005, 'batch_size': 128}
# → Val AUC: 0.96133 | Best so far: 0.97118
#
# [Trial 9/25] Params: {'num_heads': 8, 'ff_dim': 256, 'num_transformer_blocks': 4, 'dropout_rate': 0.1, 'learning_rate': 0.0005, 'batch_size': 64}
# → Val AUC: 0.96451 | Best so far: 0.97118
#
# [Trial 10/25] Params: {'num_heads': 4, 'ff_dim': 64, 'num_transformer_blocks': 3, 'dropout_rate': 0.1, 'learning_rate': 0.0001, 'batch_size': 128}
# → Val AUC: 0.96309 | Best so far: 0.97118
#
# [Trial 11/25] Params: {'num_heads': 8, 'ff_dim': 256, 'num_transformer_blocks': 3, 'dropout_rate': 0.3, 'learning_rate': 0.0005, 'batch_size': 32}
# → Val AUC: 0.95627 | Best so far: 0.97118
#
# [Trial 12/25] Params: {'num_heads': 8, 'ff_dim': 128, 'num_transformer_blocks': 2, 'dropout_rate': 0.2, 'learning_rate': 0.0001, 'batch_size': 32}
# → Val AUC: 0.96082 | Best so far: 0.97118
#
# [Trial 13/25] Params: {'num_heads': 4, 'ff_dim': 64, 'num_transformer_blocks': 4, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 32}
# → Val AUC: 0.95713 | Best so far: 0.97118
#
# [Trial 14/25] Params: {'num_heads': 4, 'ff_dim': 256, 'num_transformer_blocks': 4, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 128}
# → Val AUC: 0.95675 | Best so far: 0.97118
#
# [Trial 15/25] Params: {'num_heads': 4, 'ff_dim': 256, 'num_transformer_blocks': 2, 'dropout_rate': 0.1, 'learning_rate': 0.0001, 'batch_size': 128}
# → Val AUC: 0.95629 | Best so far: 0.97118
#
# [Trial 16/25] Params: {'num_heads': 4, 'ff_dim': 256, 'num_transformer_blocks': 4, 'dropout_rate': 0.2, 'learning_rate': 0.0001, 'batch_size': 32}
# → Val AUC: 0.97010 | Best so far: 0.97118
#
# [Trial 17/25] Params: {'num_heads': 2, 'ff_dim': 256, 'num_transformer_blocks': 3, 'dropout_rate': 0.1, 'learning_rate': 0.0001, 'batch_size': 32}
# → Val AUC: 0.96058 | Best so far: 0.97118
#
# [Trial 18/25] Params: {'num_heads': 8, 'ff_dim': 64, 'num_transformer_blocks': 4, 'dropout_rate': 0.3, 'learning_rate': 0.0001, 'batch_size': 64}
# → Val AUC: 0.94660 | Best so far: 0.97118
#
# [Trial 19/25] Params: {'num_heads': 4, 'ff_dim': 256, 'num_transformer_blocks': 2, 'dropout_rate': 0.3, 'learning_rate': 0.0005, 'batch_size': 64}
# → Val AUC: 0.95396 | Best so far: 0.97118
#
# [Trial 20/25] Params: {'num_heads': 4, 'ff_dim': 128, 'num_transformer_blocks': 2, 'dropout_rate': 0.1, 'learning_rate': 0.001, 'batch_size': 32}
# → Val AUC: 0.95436 | Best so far: 0.97118
#
# [Trial 21/25] Params: {'num_heads': 4, 'ff_dim': 256, 'num_transformer_blocks': 3, 'dropout_rate': 0.2, 'learning_rate': 0.0001, 'batch_size': 64}
# → Val AUC: 0.95515 | Best so far: 0.97118
#
# [Trial 22/25] Params: {'num_heads': 2, 'ff_dim': 256, 'num_transformer_blocks': 3, 'dropout_rate': 0.2, 'learning_rate': 0.0005, 'batch_size': 64}
# → Val AUC: 0.96865 | Best so far: 0.97118
#
# [Trial 23/25] Params: {'num_heads': 2, 'ff_dim': 128, 'num_transformer_blocks': 4, 'dropout_rate': 0.1, 'learning_rate': 0.0005, 'batch_size': 32}
# → Val AUC: 0.95703 | Best so far: 0.97118
#
# [Trial 24/25] Params: {'num_heads': 4, 'ff_dim': 128, 'num_transformer_blocks': 4, 'dropout_rate': 0.1, 'learning_rate': 0.001, 'batch_size': 64}
# → Val AUC: 0.96356 | Best so far: 0.97118
#
# [Trial 25/25] Params: {'num_heads': 8, 'ff_dim': 256, 'num_transformer_blocks': 2, 'dropout_rate': 0.1, 'learning_rate': 0.0001, 'batch_size': 32}
# → Val AUC: 0.95709 | Best so far: 0.97118
#
# === Random Search Summary ===
#     num_heads  ff_dim  num_transformer_blocks  dropout_rate  learning_rate  \
# 3           8     128                       3           0.2         0.0010
# 15          4     256                       4           0.2         0.0001
# 21          2     256                       3           0.2         0.0005
# 6           8     256                       2           0.2         0.0010
# 8           8     256                       4           0.1         0.0005
#
#     batch_size       AUC  Accuracy
# 3          128  0.971185  0.901578
# 15          32  0.970096  0.926488
# 21          64  0.968650  0.902430
# 6          128  0.965035  0.900879
# 8           64  0.964507  0.917698
#
# Best Hyperparameters: {'num_heads': 8, 'ff_dim': 128, 'num_transformer_blocks': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 128}
# Best parameters found: {'num_heads': 8, 'ff_dim': 128, 'num_transformer_blocks': 3, 'dropout_rate': 0.2, 'learning_rate': 0.001, 'batch_size': 128}
# Model structure diagram saved to /home/g_kirubavathi/Amal/1_XNFT_R1/R2/plots_r2_NF-CSE-CIC-IDS2018./transformer_model_structure.png
#
# Model Summary:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Flow_Input (InputLayer)     [(None, 5, 2)]            0
#
#  transformer_block (Transfor  (None, 5, 2)             11916
#  merBlock)
#
#  transformer_block_1 (Transf  (None, 5, 2)             11916
#  ormerBlock)
#
#  transformer_block_2 (Transf  (None, 5, 2)             11916
#  ormerBlock)
#
#  flatten (Flatten)           (None, 10)                0
#
#  dense_6 (Dense)             (None, 64)                704
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  Binary_Output (Dense)       (None, 1)                 65
#
# =================================================================
# Total params: 36,517
# Trainable params: 36,517
# Non-trainable params: 0
# _________________________________________________________________
# Sanity check:
#   X_train_seq: (131513, 5, 2)
#   y_train: 131513
#   X_test_seq: (13758, 5, 2)
#   y_test: 13758
#   X_val_seq: (32879, 5, 2)
#   y_val: 32879
# SHAPES:
#   train_data: (164392, 14)  test_data: (13758, 14)
#   X_train_cleaned: (131513, 10)  y_train: 131513
#   X_test_cleaned: (13758, 10)  y_test: 13758
#   X_train_seq: (131513, 5, 2)  X_test_seq: (13758, 5, 2)
# Epoch 1/50
# 1028/1028 [==============================] - 28s 24ms/step - loss: 0.2699 - accuracy: 0.8910 - auc: 0.9487 - val_loss: 0.2323 - val_accuracy: 0.9032 - val_auc: 0.9572
# Epoch 2/50
# 1028/1028 [==============================] - 25s 24ms/step - loss: 0.2388 - accuracy: 0.9016 - auc: 0.9557 - val_loss: 0.2323 - val_accuracy: 0.9032 - val_auc: 0.9572
# Epoch 3/50
# 1028/1028 [==============================] - 27s 26ms/step - loss: 0.2378 - accuracy: 0.9016 - auc: 0.9561 - val_loss: 0.2318 - val_accuracy: 0.9032 - val_auc: 0.9572
# Epoch 4/50
# 1028/1028 [==============================] - 31s 30ms/step - loss: 0.2365 - accuracy: 0.9017 - auc: 0.9563 - val_loss: 0.2317 - val_accuracy: 0.9032 - val_auc: 0.9572
# Epoch 5/50
# 1028/1028 [==============================] - 42s 41ms/step - loss: 0.2370 - accuracy: 0.9017 - auc: 0.9558 - val_loss: 0.2311 - val_accuracy: 0.9032 - val_auc: 0.9573
# Epoch 6/50
# 1028/1028 [==============================] - 46s 44ms/step - loss: 0.2362 - accuracy: 0.9015 - auc: 0.9563 - val_loss: 0.2309 - val_accuracy: 0.9032 - val_auc: 0.9573
# Epoch 7/50
# 1028/1028 [==============================] - 62s 60ms/step - loss: 0.2360 - accuracy: 0.9015 - auc: 0.9564 - val_loss: 0.2308 - val_accuracy: 0.9032 - val_auc: 0.9573
# Epoch 8/50
# 1028/1028 [==============================] - 53s 51ms/step - loss: 0.2358 - accuracy: 0.9015 - auc: 0.9563 - val_loss: 0.2308 - val_accuracy: 0.9032 - val_auc: 0.9573
# Epoch 9/50
# 1028/1028 [==============================] - 55s 54ms/step - loss: 0.2351 - accuracy: 0.9019 - auc: 0.9567 - val_loss: 0.2304 - val_accuracy: 0.9032 - val_auc: 0.9573
# Epoch 10/50
# 1028/1028 [==============================] - 62s 60ms/step - loss: 0.2355 - accuracy: 0.9017 - auc: 0.9564 - val_loss: 0.2308 - val_accuracy: 0.9032 - val_auc: 0.9573
# Epoch 11/50
# 1028/1028 [==============================] - 33s 32ms/step - loss: 0.2358 - accuracy: 0.9016 - auc: 0.9561 - val_loss: 0.2303 - val_accuracy: 0.9032 - val_auc: 0.9573
# Epoch 12/50
# 1028/1028 [==============================] - 25s 25ms/step - loss: 0.2355 - accuracy: 0.9015 - auc: 0.9565 - val_loss: 0.2305 - val_accuracy: 0.9032 - val_auc: 0.9573
# Epoch 13/50
# 1028/1028 [==============================] - 26s 25ms/step - loss: 0.2355 - accuracy: 0.9016 - auc: 0.9563 - val_loss: 0.2309 - val_accuracy: 0.9032 - val_auc: 0.9573
# Epoch 14/50
# 1028/1028 [==============================] - 24s 24ms/step - loss: 0.2357 - accuracy: 0.9014 - auc: 0.9562 - val_loss: 0.2306 - val_accuracy: 0.9032 - val_auc: 0.9573
# Epoch 15/50
# 1028/1028 [==============================] - 25s 24ms/step - loss: 0.2351 - accuracy: 0.9019 - auc: 0.9563 - val_loss: 0.2304 - val_accuracy: 0.9032 - val_auc: 0.9573
# Epoch 16/50
# 1028/1028 [==============================] - 31s 30ms/step - loss: 0.2353 - accuracy: 0.9017 - auc: 0.9563 - val_loss: 0.2303 - val_accuracy: 0.9032 - val_auc: 0.9573
# Epoch 17/50
# 1028/1028 [==============================] - 44s 43ms/step - loss: 0.2355 - accuracy: 0.9015 - auc: 0.9563 - val_loss: 0.2304 - val_accuracy: 0.9032 - val_auc: 0.9573
# Epoch 18/50
# 1028/1028 [==============================] - 51s 49ms/step - loss: 0.2356 - accuracy: 0.9015 - auc: 0.9561 - val_loss: 0.2302 - val_accuracy: 0.9032 - val_auc: 0.9573
# Epoch 19/50
# 1028/1028 [==============================] - 61s 59ms/step - loss: 0.2354 - accuracy: 0.9017 - auc: 0.9563 - val_loss: 0.2308 - val_accuracy: 0.9032 - val_auc: 0.9573
# Epoch 20/50
# 1028/1028 [==============================] - 57s 55ms/step - loss: 0.2357 - accuracy: 0.9014 - auc: 0.9562 - val_loss: 0.2302 - val_accuracy: 0.9032 - val_auc: 0.9573
# Epoch 21/50
# 1028/1028 [==============================] - 53s 52ms/step - loss: 0.2353 - accuracy: 0.9015 - auc: 0.9565 - val_loss: 0.2305 - val_accuracy: 0.9032 - val_auc: 0.9573
# Epoch 22/50
# 1028/1028 [==============================] - 62s 61ms/step - loss: 0.2353 - accuracy: 0.9015 - auc: 0.9562 - val_loss: 0.2302 - val_accuracy: 0.9032 - val_auc: 0.9573
# Epoch 23/50
# 1028/1028 [==============================] - 32s 31ms/step - loss: 0.2351 - accuracy: 0.9018 - auc: 0.9566 - val_loss: 0.2303 - val_accuracy: 0.9032 - val_auc: 0.9573
# ROC AUC Score: 1.0
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      4855
#            1       1.00      0.95      0.98      8903
#
#     accuracy                           0.97     13758
#    macro avg       0.96      0.98      0.97     13758
# weighted avg       0.97      0.97      0.97     13758
# [saved] /home/g_kirubavathi/Amal/1_XNFT_R1/R2/plots_r2_NF-CSE-CIC-IDS2018./loss_plot.png
# [saved] /home/g_kirubavathi/Amal/1_XNFT_R1/R2/plots_r2_NF-CSE-CIC-IDS2018./accuracy_plot.png
# [saved] /home/g_kirubavathi/Amal/1_XNFT_R1/R2/plots_r2_NF-CSE-CIC-IDS2018./evaluation_metrics.txt
# [saved] /home/g_kirubavathi/Amal/1_XNFT_R1/R2/plots_r2_NF-CSE-CIC-IDS2018./roc_curve.png
# [saved] /home/g_kirubavathi/Amal/1_XNFT_R1/R2/plots_r2_NF-CSE-CIC-IDS2018./precision_recall_curve.png
# Precision=1.000000 Recall=0.953386 F1=0.976137 AUC=1.000000
# [saved] /home/g_kirubavathi/Amal/1_XNFT_R1/R2/plots_r2_NF-CSE-CIC-IDS2018./confusion_matrix.png
# Confusion Matrix:
#  [[4855    0]
#  [ 415 8488]]
# 2026-02-07 16:49:59.096342: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:absl:Function `_wrapped_model` contains input name(s) Flow_Input with unsupported characters which will be renamed to flow_input in the SavedModel.
# WARNING:absl:Found untraced functions such as multi_head_attention_layer_call_fn, multi_head_attention_layer_call_and_return_conditional_losses, layer_normalization_layer_call_fn, layer_normalization_layer_call_and_return_conditional_losses, layer_normalization_1_layer_call_fn while saving (showing 5 of 165). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/g_kirubavathi/Amal/1_XNFT_R1/R2/plots_r2_NF-CSE-CIC-IDS2018./bench_min/savedmodel/assets
# INFO:tensorflow:Assets written to: /home/g_kirubavathi/Amal/1_XNFT_R1/R2/plots_r2_NF-CSE-CIC-IDS2018./bench_min/savedmodel/assets
# Params: 36,517
# Model size — SavedModel: 1.153 MB, H5: 0.206 MB
# CPU bs=1 → per-sample p50: 42.415 ms
# GPU bs=1 → per-sample p50: 45.459 ms
# [saved] /home/g_kirubavathi/Amal/1_XNFT_R1/R2/plots_r2_NF-CSE-CIC-IDS2018./timings/timing_summary.csv
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:   0%|▎                                                   | 1/200 [00:00<?, ?it/s]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:   2%|▋                                           | 3/200 [00:44<31:10,  9.49s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:   2%|▉                                           | 4/200 [01:04<45:33, 13.95s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:   2%|█                                           | 5/200 [01:25<53:45, 16.54s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:   3%|█▎                                          | 6/200 [01:46<58:18, 18.03s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:   4%|█▍                                        | 7/200 [02:08<1:02:20, 19.38s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:   4%|█▋                                        | 8/200 [02:39<1:14:33, 23.30s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:   4%|█▉                                        | 9/200 [03:18<1:29:52, 28.23s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:   5%|██                                       | 10/200 [03:52<1:35:13, 30.07s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:   6%|██▎                                      | 11/200 [04:20<1:32:41, 29.42s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:   6%|██▍                                      | 12/200 [04:49<1:31:00, 29.04s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:   6%|██▋                                      | 13/200 [05:33<1:44:57, 33.68s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:   7%|██▊                                      | 14/200 [06:02<1:40:02, 32.27s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:   8%|███                                      | 15/200 [06:41<1:45:49, 34.32s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:   8%|███▎                                     | 16/200 [07:35<2:03:38, 40.32s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:   8%|███▍                                     | 17/200 [07:51<1:40:09, 32.84s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:   9%|███▋                                     | 18/200 [08:10<1:27:29, 28.84s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  10%|███▉                                     | 19/200 [08:24<1:13:43, 24.44s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  10%|████                                     | 20/200 [08:39<1:04:51, 21.62s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  10%|████▎                                    | 21/200 [08:56<1:00:19, 20.22s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  11%|████▋                                      | 22/200 [09:10<54:04, 18.23s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  12%|████▉                                      | 23/200 [09:29<54:19, 18.41s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  12%|█████▏                                     | 24/200 [09:47<54:10, 18.47s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  12%|█████▍                                     | 25/200 [10:11<58:17, 19.99s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  13%|█████▎                                   | 26/200 [10:36<1:02:29, 21.55s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  14%|█████▌                                   | 27/200 [11:01<1:05:07, 22.59s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  14%|█████▋                                   | 28/200 [11:40<1:18:47, 27.49s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  14%|█████▉                                   | 29/200 [12:10<1:20:27, 28.23s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  15%|██████▏                                  | 30/200 [12:42<1:23:19, 29.41s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  16%|██████▎                                  | 31/200 [13:08<1:20:10, 28.47s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  16%|██████▌                                  | 32/200 [13:58<1:37:48, 34.93s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  16%|██████▊                                  | 33/200 [14:47<1:48:37, 39.03s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  17%|██████▉                                  | 34/200 [15:09<1:33:52, 33.93s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  18%|███████▏                                 | 35/200 [16:03<1:49:55, 39.97s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  18%|███████▍                                 | 36/200 [16:18<1:28:26, 32.36s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  18%|███████▌                                 | 37/200 [16:37<1:17:25, 28.50s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  19%|███████▊                                 | 38/200 [16:57<1:09:41, 25.81s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  20%|███████▉                                 | 39/200 [17:17<1:04:52, 24.17s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  20%|████████▌                                  | 40/200 [17:32<57:14, 21.47s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  20%|████████▊                                  | 41/200 [17:51<54:41, 20.64s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  21%|█████████                                  | 42/200 [18:07<50:28, 19.17s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  22%|█████████▏                                 | 43/200 [18:25<49:44, 19.01s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  22%|█████████▍                                 | 44/200 [18:45<49:32, 19.05s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  22%|█████████▋                                 | 45/200 [19:04<49:45, 19.26s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  23%|█████████▉                                 | 46/200 [19:24<49:58, 19.47s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  24%|██████████                                 | 47/200 [19:56<59:21, 23.28s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  24%|█████████▊                               | 48/200 [20:36<1:11:40, 28.29s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  24%|██████████                               | 49/200 [21:17<1:20:42, 32.07s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  25%|██████████▎                              | 50/200 [21:37<1:11:04, 28.43s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  26%|██████████▍                              | 51/200 [22:18<1:19:42, 32.09s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  26%|██████████▋                              | 52/200 [23:08<1:32:11, 37.38s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  26%|██████████▊                              | 53/200 [23:34<1:23:12, 33.96s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  27%|███████████                              | 54/200 [24:16<1:29:12, 36.66s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  28%|███████████▎                             | 55/200 [24:37<1:17:11, 31.94s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  28%|███████████▍                             | 56/200 [24:51<1:03:27, 26.44s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  28%|████████████▎                              | 57/200 [25:11<58:04, 24.37s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  29%|████████████▍                              | 58/200 [25:24<49:49, 21.05s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  30%|████████████▋                              | 59/200 [25:43<48:07, 20.48s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  30%|████████████▉                              | 60/200 [26:03<47:27, 20.34s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  30%|█████████████                              | 61/200 [26:20<44:35, 19.25s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  31%|█████████████▎                             | 62/200 [26:33<40:27, 17.59s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  32%|█████████████▌                             | 63/200 [26:52<40:43, 17.83s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  32%|█████████████▊                             | 64/200 [27:16<44:30, 19.63s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  32%|█████████████▉                             | 65/200 [27:43<49:15, 21.90s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  33%|██████████████▏                            | 66/200 [27:57<43:44, 19.58s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  34%|██████████████▍                            | 67/200 [28:23<47:34, 21.47s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  34%|██████████████▌                            | 68/200 [28:58<56:25, 25.65s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  34%|██████████████▏                          | 69/200 [29:40<1:06:26, 30.43s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  35%|██████████████▎                          | 70/200 [30:03<1:01:25, 28.35s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  36%|██████████████▌                          | 71/200 [30:46<1:10:07, 32.62s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  36%|██████████████▊                          | 72/200 [31:31<1:17:35, 36.37s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  36%|██████████████▉                          | 73/200 [31:56<1:09:25, 32.80s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  37%|███████████████▏                         | 74/200 [32:50<1:22:42, 39.39s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  38%|███████████████▍                         | 75/200 [33:12<1:10:42, 33.94s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  38%|████████████████▎                          | 76/200 [33:27<58:58, 28.53s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  38%|████████████████▌                          | 77/200 [33:46<52:17, 25.51s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  39%|████████████████▊                          | 78/200 [34:00<45:11, 22.22s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  40%|████████████████▉                          | 79/200 [34:18<42:06, 20.88s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  40%|█████████████████▏                         | 80/200 [34:36<39:44, 19.87s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  40%|█████████████████▍                         | 81/200 [34:51<36:45, 18.54s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  41%|█████████████████▋                         | 82/200 [35:04<33:15, 16.91s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  42%|█████████████████▊                         | 83/200 [35:25<35:02, 17.97s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  42%|██████████████████                         | 84/200 [35:51<39:27, 20.41s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  42%|██████████████████▎                        | 85/200 [36:18<43:09, 22.52s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  43%|██████████████████▍                        | 86/200 [36:41<42:37, 22.43s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  44%|██████████████████▋                        | 87/200 [37:19<51:28, 27.33s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  44%|██████████████████▉                        | 88/200 [37:34<43:56, 23.54s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  44%|███████████████████▏                       | 89/200 [38:14<52:51, 28.57s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  45%|███████████████████▎                       | 90/200 [38:45<53:34, 29.23s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  46%|███████████████████▌                       | 91/200 [39:12<52:01, 28.63s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  46%|███████████████████▊                       | 92/200 [39:54<58:35, 32.55s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  46%|███████████████████▉                       | 93/200 [40:16<52:31, 29.45s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  47%|███████████████████▎                     | 94/200 [41:15<1:07:23, 38.15s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  48%|████████████████████▍                      | 95/200 [41:30<54:38, 31.23s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  48%|████████████████████▋                      | 96/200 [41:48<47:27, 27.38s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  48%|████████████████████▊                      | 97/200 [42:04<41:01, 23.90s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  49%|█████████████████████                      | 98/200 [42:21<37:14, 21.91s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  50%|█████████████████████▎                     | 99/200 [42:39<34:54, 20.73s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  50%|█████████████████████                     | 100/200 [42:58<33:24, 20.05s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  50%|█████████████████████▏                    | 101/200 [43:16<32:04, 19.44s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  51%|█████████████████████▍                    | 102/200 [43:31<29:58, 18.36s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  52%|█████████████████████▋                    | 103/200 [43:49<29:18, 18.13s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  52%|█████████████████████▊                    | 104/200 [44:10<30:18, 18.95s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  52%|██████████████████████                    | 105/200 [44:34<32:40, 20.64s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  53%|██████████████████████▎                   | 106/200 [45:07<37:58, 24.24s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  54%|██████████████████████▍                   | 107/200 [45:43<43:11, 27.87s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ...
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  76%|██████████████████████████████▍         | 152/200 [1:03:07<22:32, 28.17s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  76%|██████████████████████████████▌         | 153/200 [1:03:50<25:30, 32.56s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  77%|██████████████████████████████▊         | 154/200 [1:04:24<25:17, 32.99s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  78%|███████████████████████████████         | 155/200 [1:04:57<24:38, 32.85s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  78%|███████████████████████████████▏        | 156/200 [1:05:12<20:17, 27.67s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  78%|███████████████████████████████▍        | 157/200 [1:06:00<24:15, 33.85s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  79%|███████████████████████████████▌        | 158/200 [1:06:15<19:34, 27.97s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  80%|███████████████████████████████▊        | 159/200 [1:06:32<16:55, 24.77s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  80%|████████████████████████████████        | 160/200 [1:06:48<14:45, 22.15s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  80%|████████████████████████████████▏       | 161/200 [1:07:04<13:05, 20.13s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  81%|████████████████████████████████▍       | 162/200 [1:07:16<11:12, 17.69s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  82%|████████████████████████████████▌       | 163/200 [1:07:34<10:59, 17.81s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  82%|████████████████████████████████▊       | 164/200 [1:07:48<09:59, 16.64s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  82%|█████████████████████████████████       | 165/200 [1:08:00<08:55, 15.30s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  83%|█████████████████████████████████▏      | 166/200 [1:08:15<08:37, 15.22s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  84%|█████████████████████████████████▍      | 167/200 [1:08:29<08:17, 15.07s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  84%|█████████████████████████████████▌      | 168/200 [1:08:46<08:14, 15.46s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  84%|█████████████████████████████████▊      | 169/200 [1:09:08<09:03, 17.53s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  85%|██████████████████████████████████      | 170/200 [1:09:36<10:17, 20.58s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  86%|██████████████████████████████████▏     | 171/200 [1:10:05<11:10, 23.12s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  86%|██████████████████████████████████▍     | 172/200 [1:10:39<12:15, 26.27s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  86%|██████████████████████████████████▌     | 173/200 [1:10:52<10:09, 22.56s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  87%|██████████████████████████████████▊     | 174/200 [1:11:27<11:20, 26.17s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  88%|███████████████████████████████████     | 175/200 [1:11:43<09:37, 23.10s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  88%|███████████████████████████████████▏    | 176/200 [1:12:22<11:07, 27.83s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  88%|███████████████████████████████████▍    | 177/200 [1:12:38<09:20, 24.37s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  89%|███████████████████████████████████▌    | 178/200 [1:13:20<10:53, 29.72s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  90%|███████████████████████████████████▊    | 179/200 [1:13:42<09:35, 27.42s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  90%|████████████████████████████████████    | 180/200 [1:14:37<11:51, 35.60s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  90%|████████████████████████████████████▏   | 181/200 [1:14:58<09:53, 31.26s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  91%|████████████████████████████████████▍   | 182/200 [1:15:18<08:18, 27.70s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  92%|████████████████████████████████████▌   | 183/200 [1:15:35<06:56, 24.49s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  92%|████████████████████████████████████▊   | 184/200 [1:15:52<05:58, 22.39s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  92%|█████████████████████████████████████   | 185/200 [1:16:08<05:08, 20.54s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  93%|█████████████████████████████████████▏  | 186/200 [1:16:25<04:29, 19.26s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  94%|█████████████████████████████████████▍  | 187/200 [1:16:44<04:10, 19.30s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  94%|█████████████████████████████████████▌  | 188/200 [1:17:03<03:49, 19.10s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  94%|█████████████████████████████████████▊  | 189/200 [1:17:23<03:33, 19.37s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  95%|██████████████████████████████████████  | 190/200 [1:17:51<03:41, 22.13s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  96%|██████████████████████████████████████▏ | 191/200 [1:18:26<03:52, 25.81s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  96%|██████████████████████████████████████▍ | 192/200 [1:19:02<03:51, 28.92s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  96%|██████████████████████████████████████▌ | 193/200 [1:19:33<03:26, 29.48s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  97%|██████████████████████████████████████▊ | 194/200 [1:20:03<02:58, 29.70s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  98%|███████████████████████████████████████ | 195/200 [1:20:53<02:59, 35.95s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  98%|███████████████████████████████████████▏| 196/200 [1:21:41<02:38, 39.61s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  98%|███████████████████████████████████████▍| 197/200 [1:22:02<01:41, 33.78s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer:  99%|███████████████████████████████████████▌| 198/200 [1:22:53<01:17, 38.97s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer: 100%|███████████████████████████████████████▊| 199/200 [1:23:15<00:34, 34.01s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer: 100%|████████████████████████████████████████| 200/200 [1:23:28<00:00, 27.65s/it]X does not have valid feature names, but StandardScaler was fitted with feature names
# X does not have valid feature names, but StandardScaler was fitted with feature names
# ExactExplainer explainer: 201it [1:23:41, 25.11s/it]
# X does not have valid feature names, but StandardScaler was fitted with feature names
# [saved] /home/g_kirubavathi/Amal/1_XNFT_R1/R2/plots_r2_NF-CSE-CIC-IDS2018./lime/lime_explanation_sample_1182.html
# X does not have valid feature names, but StandardScaler was fitted with feature names
# [saved] /home/g_kirubavathi/Amal/1_XNFT_R1/R2/plots_r2_NF-CSE-CIC-IDS2018./lime/lime_explanation_sample_10641.html
# X does not have valid feature names, but StandardScaler was fitted with feature names
# [saved] /home/g_kirubavathi/Amal/1_XNFT_R1/R2/plots_r2_NF-CSE-CIC-IDS2018./lime/lime_explanation_sample_1227.html
# X does not have valid feature names, but StandardScaler was fitted with feature names
# [saved] /home/g_kirubavathi/Amal/1_XNFT_R1/R2/plots_r2_NF-CSE-CIC-IDS2018./lime/lime_explanation_sample_9001.html
# X does not have valid feature names, but StandardScaler was fitted with feature names
# [saved] /home/g_kirubavathi/Amal/1_XNFT_R1/R2/plots_r2_NF-CSE-CIC-IDS2018./lime/lime_explanation_sample_6035.html
# X does not have valid feature names, but StandardScaler was fitted with feature names
# [saved] /home/g_kirubavathi/Amal/1_XNFT_R1/R2/plots_r2_NF-CSE-CIC-IDS2018./lime/lime_explanation_sample_5955.html
# X does not have valid feature names, but StandardScaler was fitted with feature names
# [saved] /home/g_kirubavathi/Amal/1_XNFT_R1/R2/plots_r2_NF-CSE-CIC-IDS2018./lime/lime_explanation_sample_9592.html
# X does not have valid feature names, but StandardScaler was fitted with feature names
# [saved] /home/g_kirubavathi/Amal/1_XNFT_R1/R2/plots_r2_NF-CSE-CIC-IDS2018./lime/lime_explanation_sample_1295.html
# X does not have valid feature names, but StandardScaler was fitted with feature names
# [saved] /home/g_kirubavathi/Amal/1_XNFT_R1/R2/plots_r2_NF-CSE-CIC-IDS2018./lime/lime_explanation_sample_2771.html
# X does not have valid feature names, but StandardScaler was fitted with feature names
# [saved] /home/g_kirubavathi/Amal/1_XNFT_R1/R2/plots_r2_NF-CSE-CIC-IDS2018./lime/lime_explanation_sample_11809.html
# Dataset: NF-ToN-IoT.csv
